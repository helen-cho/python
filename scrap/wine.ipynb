# %%
import pandas as pd
df = pd.read_csv('data/WineInfo_Red_detail.csv')
df.head()
# Out:
#    index                                 wine_name wine_country  \
# 0      1                       Bordeaux Rouge 1961       France
# 1      2                 Côtes-du-Rhône Rouge 1993       France
# 2      3  Pauillac (Premier Grand Cru Classé) 1954       France
# 3      4  Pauillac (Premier Grand Cru Classé) 1939       France
# 4      5                         Memoro Rosso N.V.        Italy
#
#       wine_region                wine_winery wine_type wine_grape  \
# 0        Bordeaux               Mouton Cadet  Red wine      Blend
# 1  Côtes-du-Rhône                  E. Guigal  Red wine      Blend
# 2        Pauillac  Château Mouton Rothschild  Red wine      Blend
# 3        Pauillac  Château Mouton Rothschild  Red wine      Blend
# 4         Toscana                    Piccini  Red wine      Blend
#
#                                           wine_image               body  \
# 0  https://images.vivino.com/thumbs/UN_lNptVQHG8E...  67.16929999999999
# ...

# %%
query='france'
filt = (df['wine_name'].str.lower().str.contains(query)) | (df['wine_country'].str.lower().str.contains(query))
df[filt].head(5)
len(df[filt])
# Out:
# 815
