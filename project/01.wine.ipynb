# %%
import pandas as pd

# %%
df = pd.read_csv('data/wineInfo_RedV2.csv')
data = df.iloc[:10]
data
# Out:
#    index                                        wine_name  \
# 0      1                              Bordeaux Rouge 1961
# 1      2                        Côtes-du-Rhône Rouge 1993
# 2      3         Pauillac (Premier Grand Cru Classé) 1954
# 3      4         Pauillac (Premier Grand Cru Classé) 1939
# 4      5                                Memoro Rosso N.V.
# 5      6                             Portillo Malbec 2002
# 6      7                             Portillo Malbec 2004
# 7      8  Château Margaux (Premier Grand Cru Classé) 1918
# 8      9  Château Margaux (Premier Grand Cru Classé) 1948
# 9     10             Saint-Julien (Grand Cru Classé) 1968
#
#                  wine_region wine_country  wine_rating  wine_reviews  \
# 0               Mouton Cadet       France          3.5        105422
# 1                  E. Guigal       France          3.7         85268
# 2  Château Mouton Rothschild       France          4.6         80795
# ...
